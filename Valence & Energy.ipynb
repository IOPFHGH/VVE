# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\harsh\Downloads\spotify dataset.csv")
df
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
df.isnull().sum()
# Out:
# track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
df.track_name=df.track_name.fillna("VACUUM")
df.track_artist=df.track_artist.fillna("VACUUM")
df.track_album_name=df.track_album_name.fillna("VACUUM")

# %%
df.isnull().sum()
# Out:
# track_id                    0
# track_name                  0
# track_artist                0
# track_popularity            0
# track_album_id              0
# track_album_name            0
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
df1=df.sort_values('track_popularity',ascending=False).head(100)
df1
# Out:
#                      track_id           track_name    track_artist  \
# 20091  2XU0oxnq2qxCpomAAuJY8K         Dance Monkey     Tones and I
# 1551   2XU0oxnq2qxCpomAAuJY8K         Dance Monkey     Tones and I
# 30202  696DnlkuDOXcMAnKlTgXXK              ROXANNE  Arizona Zervas
# 23104  696DnlkuDOXcMAnKlTgXXK              ROXANNE  Arizona Zervas
# 21468  696DnlkuDOXcMAnKlTgXXK              ROXANNE  Arizona Zervas
# ...                       ...                  ...             ...
# 19748  7aiClxsDWFRQ0Kzk5KI5ku      hot girl bummer       blackbear
# 1306   7aiClxsDWFRQ0Kzk5KI5ku      hot girl bummer       blackbear
# 1304   7qEHsqek33rTcFNT9PFqLf    Someone You Loved   Lewis Capaldi
# 1303   3eekarcy7kvN4yt5ZFzltW  HIGHEST IN THE ROOM    Travis Scott
# 8981   3eekarcy7kvN4yt5ZFzltW  HIGHEST IN THE ROOM    Travis Scott
#
#        track_popularity          track_album_id  \
# 20091               100  0UywfDKYlyiu1b38DRrzYD
# 1551                100  0UywfDKYlyiu1b38DRrzYD
# ...

# %%
df1
# Out:
#                      track_id           track_name    track_artist  \
# 20091  2XU0oxnq2qxCpomAAuJY8K         Dance Monkey     Tones and I
# 1551   2XU0oxnq2qxCpomAAuJY8K         Dance Monkey     Tones and I
# 30202  696DnlkuDOXcMAnKlTgXXK              ROXANNE  Arizona Zervas
# 23104  696DnlkuDOXcMAnKlTgXXK              ROXANNE  Arizona Zervas
# 21468  696DnlkuDOXcMAnKlTgXXK              ROXANNE  Arizona Zervas
# ...                       ...                  ...             ...
# 19748  7aiClxsDWFRQ0Kzk5KI5ku      hot girl bummer       blackbear
# 1306   7aiClxsDWFRQ0Kzk5KI5ku      hot girl bummer       blackbear
# 1304   7qEHsqek33rTcFNT9PFqLf    Someone You Loved   Lewis Capaldi
# 1303   3eekarcy7kvN4yt5ZFzltW  HIGHEST IN THE ROOM    Travis Scott
# 8981   3eekarcy7kvN4yt5ZFzltW  HIGHEST IN THE ROOM    Travis Scott
#
#        track_popularity          track_album_id  \
# 20091               100  0UywfDKYlyiu1b38DRrzYD
# 1551                100  0UywfDKYlyiu1b38DRrzYD
# ...

# %%
plt.scatter(df1.valence,df1.energy)

# %%
from sklearn.cluster import KMeans
kmeans_model=KMeans(n_clusters=6)
kmeans_model.fit(df1[["valence","energy"]])
# Out:
# C:\Users\harsh\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\harsh\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=6)

# %%
kmeans_model.cluster_centers_
# Out:
# array([[0.6503    , 0.70575   ],
#        [0.243     , 0.225     ],
#        [0.47233333, 0.54633333],
#        [0.345     , 0.796     ],
#        [0.55488889, 0.37611111],
#        [0.15622727, 0.42863636]])

# %%
df1["cluster_group"]=kmeans_model.labels_

# %%
x=df.iloc[:,12:]
x
# Out:
#        energy  key  loudness  mode  speechiness  acousticness  \
# 0       0.916    6    -2.634     1       0.0583      0.102000
# 1       0.815   11    -4.969     1       0.0373      0.072400
# 2       0.931    1    -3.432     0       0.0742      0.079400
# 3       0.930    7    -3.778     1       0.1020      0.028700
# 4       0.833    1    -4.672     1       0.0359      0.080300
# ...       ...  ...       ...   ...          ...           ...
# 32828   0.922    2    -1.814     1       0.0936      0.076600
# 32829   0.786    0    -4.462     1       0.0420      0.001710
# 32830   0.821    6    -4.899     0       0.0481      0.108000
# 32831   0.888    2    -3.361     1       0.1090      0.007920
# 32832   0.884    5    -4.571     0       0.0385      0.000133
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 0              0.000000    0.0653   0.5180  122.036       194754
# 1              0.004210    0.3570   0.6930   99.972       162600
# ...

# %%
df1["cluster_group"].value_counts()
# Out:
# 0    40
# 4    18
# 2    15
# 5    11
# 3     8
# 1     8
# Name: cluster_group, dtype: int64

# %%
import seaborn as sns
sns.scatterplot(x="valence",y="energy",data=df1,hue="cluster_group")
# Out:
# <Axes: xlabel='valence', ylabel='energy'>

# %%
df2=df1.loc[:,['valence','energy']]
df2
# Out:
#        valence  energy
# 20091   0.5130   0.588
# 1551    0.5130   0.588
# 30202   0.4570   0.601
# 23104   0.4570   0.601
# 21468   0.4570   0.601
# ...        ...     ...
# 19748   0.6780   0.559
# 1306    0.6780   0.559
# 1304    0.4460   0.405
# 1303    0.0605   0.427
# 8981    0.0605   0.427
#
# [100 rows x 2 columns]

# %%
matrix=df2.corr()
matrix
# Out:
#           valence    energy
# valence  1.000000  0.480221
# energy   0.480221  1.000000
